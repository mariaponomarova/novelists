# %% [markdown]
# # Analyse bivariée: génération, genre, continent, champ scientifique principal
#
# Pour l'importation des données, voir ces carnets sparqlbook:
# * [Occupations](../../sparqlbooks/wdt_import_occupations.sparqlbook.md)
# * [Field](../../sparqlbooks/wdt_import_fields.sparqlbook.md)
# * [Continents](../../sparqlbooks/wdt_import_citizenships.sparqlbook.md)
#
#
# Pour vérifier l'ensemble des informations disponibles, voir ce carnet sparqlbook:
# * [Information disponible](../../sparqlbooks/wdt_available_information.sparqlbook.md )

# %%
### Librairie à installer dans l'environnement conda (si on exécute en local)
# qui sera choisi pour exécuter le carnet
from SPARQLWrapper import SPARQLWrapper, JSON, TURTLE, XML, RDFXML
import pandas as pd
import numpy as np
import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns

### Module de visualisation de données
#  https://mwouts.github.io/itables/quick_start.html

from itables import init_notebook_mode, show

init_notebook_mode(all_interactive=False)
# Out:
# <script>
#     let is_dark_theme = function () {
#         // Jupyter Lab
#         if ('jpThemeLight' in document.body.dataset)
#             return (document.body.dataset.jpThemeLight === "false");
#
#         // VS Code
#         if ('vscodeThemeKind' in document.body.dataset)
#             return document.body.dataset.vscodeThemeKind.includes('dark');
#
#         // Jupyter Book
#         if ('theme' in document.documentElement.dataset)
#             return document.documentElement.dataset.theme.includes('dark');
#
#         // Default
#         return window.matchMedia('(prefers-color-scheme: dark)').matches;
#     }
#
#     if (is_dark_theme()) {
#         document.documentElement.classList.add('dark');
#     }
#     else {
#         document.documentElement.classList.remove('dark');
#     }
# </script>
# <style>:root{--dt-row-selected: 13, 110, 253;--dt-row-selected-text: 255, 255, 255;--dt-row-selected-link: 9, 10, 11;--dt-row-stripe: 0, 0, 0;--dt-row-hover: 0, 0, 0;--dt-column-ordering: 0, 0, 0;--dt-html-background: white}:root.dark{--dt-html-background: rgb(33, 37, 41)}table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{display:inline-block;box-sizing:border-box;content:"";border-top:5px solid transparent;border-left:10px solid rgba(0,0,0,.5);border-bottom:5px solid transparent;border-right:0px solid transparent}table.dataTable tr.dt-hasChild td.dt-control:before{border-top:10px solid rgba(0,0,0,.5);border-left:5px solid transparent;border-bottom:0px solid transparent;border-right:5px solid transparent}table.dataTable tfoot:empty{display:none}html.dark table.dataTable td.dt-control:before,:root[data-bs-theme=dark] table.dataTable td.dt-control:before,:root[data-theme=dark] table.dataTable td.dt-control:before{border-left-color:#ffffff80}html.dark table.dataTable tr.dt-hasChild td.dt-control:before,:root[data-bs-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before,:root[data-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before{border-top-color:#ffffff80;border-left-color:transparent}div.dt-scroll{width:100%}div.dt-scroll-body thead tr,div.dt-scroll-body tfoot tr{height:0}div.dt-scroll-body thead tr th,div.dt-scroll-body thead tr td,div.dt-scroll-body tfoot tr th,div.dt-scroll-body tfoot tr td{height:0!important;padding-top:0!important;padding-bottom:0!important;border-top-width:0px!important;border-bottom-width:0px!important}div.dt-scroll-body thead tr th div.dt-scroll-sizing,div.dt-scroll-body thead tr td div.dt-scroll-sizing,div.dt-scroll-body tfoot tr th div.dt-scroll-sizing,div.dt-scroll-body tfoot tr td div.dt-scroll-sizing{height:0!important;overflow:hidden!important}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order:before{position:absolute;display:block;bottom:50%;content:"\25b2";content:"\25b2"/""}table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order:after{position:absolute;display:block;top:50%;content:"\25bc";content:"\25bc"/""}table.dataTable thead>tr>th.dt-orderable-asc,table.dataTable thead>tr>th.dt-orderable-desc,table.dataTable thead>tr>th.dt-ordering-asc,table.dataTable thead>tr>th.dt-ordering-desc,table.dataTable thead>tr>td.dt-orderable-asc,table.dataTable thead>tr>td.dt-orderable-desc,table.dataTable thead>tr>td.dt-ordering-asc,table.dataTable thead>tr>td.dt-ordering-desc{position:relative;padding-right:30px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order{position:absolute;right:12px;top:0;bottom:0;width:12px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc spa ...

# %%
### Librairies déjà installées avec Python
import pprint
import csv
import sys

import sqlite3 as sql

import time
import datetime
from dateutil import parser

from importlib import reload
from shutil import copyfile

# %%
### Importer un module de fonctions crées ad hoc
##  ATTENTION : le fichier 'sparql_functions.py' doit se trouver 
#   dans un dossier qui se situe dans le chemin ('path') de recherche
#   vu par le présent carnet Jupyter afin que
#   l'importation fonctionne correctement

# Add parent directory to the path
sys.path.insert(0, '..')

### If you want to add the parent-parent directory,
sys.path.insert(0, '../..')


import sparql_functions as spqf

# %% [markdown]
# ## SPARQL Query qui récupère les données
#
# On exécute la requête grâce à une fonction de la librairie locale qui réalise la mise en forme

# %%
## define SPARQL enpoint
endpoint = "https://ag10gz6eypmkc7tx.allegrograph.cloud/repositories/novelists"

# %%
# query = """
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>


# SELECT  ?s (MAX(?label) as ?label) (xsd:integer(MAX(?birthDate)) as ?birthDate) 
#             ( GROUP_CONCAT(DISTINCT ?genderLabel; separator=", ") AS ?genders ) 
#             ( GROUP_CONCAT(DISTINCT ?countryLabel; separator=", ") AS ?countries )
#             ( GROUP_CONCAT(DISTINCT ?continentLabel; separator=", ") AS ?continents )
#             ( GROUP_CONCAT(DISTINCT ?occupationLabel; separator=", ") AS ?occupations )
#             ( GROUP_CONCAT(DISTINCT ?fieldLabel; separator=", ") AS ?fields )
# WHERE {
#     GRAPH <https://github.com/mariaponomarova/novelists/blob/main/Wikidata/graph/imported-data.md>
#         {?s wdt:P21 ?gender;
#             rdfs:label ?label;
#             wdt:P569 ?birthDate;
#             wdt:P27 ?country.
#         ?gender rdfs:label ?genderLabel.
#         ?country rdfs:label ?countryLabel.
#         ?country wdt:P30 ?continent.
#         ?continent rdfs:label ?continentLabel.
#         OPTIONAL {  ?s wdt:P106 ?occupation.
#                     ?occupation rdfs:label ?occupationLabel.}
#         OPTIONAL {  ?s wdt:P101 ?field.
#                     ?field rdfs:label ?fieldLabel.}

#         ## Excluding Australia and Oceania insular
#         # Eurasia : wd:Q5401 
#         FILTER ( ?continent NOT IN ( wd:Q3960, wd:Q538))
#           }
# }
# GROUP BY ?s
# LIMIT 100
# """

query = """
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>


SELECT  ?s (MAX(?label) as ?label) (xsd:integer(MAX(?birthDate)) as ?birthDate) 
            ( GROUP_CONCAT(DISTINCT ?genderLabel; separator=", ") AS ?genders ) 
            ( GROUP_CONCAT(DISTINCT ?countryLabel; separator=", ") AS ?countries )
            ( GROUP_CONCAT(DISTINCT ?continentLabel; separator=", ") AS ?continents )
            ( GROUP_CONCAT(DISTINCT ?occupationLabel; separator=", ") AS ?occupations )
            ( GROUP_CONCAT(DISTINCT ?fieldLabel; separator=", ") AS ?fields )
WHERE {
    GRAPH <https://github.com/mariaponomarova/novelists/blob/main/Wikidata/graph/imported-data.md>
        {{?s wdt:P21 ?gender;
            rdfs:label ?label;
            wdt:P569 ?birthDate;
            wdt:P27 ?country.}
        # ?gender rdfs:label ?genderLabel.
        # ?country rdfs:label ?countryLabel.
        # ?country wdt:P30 ?continent.
        # ?continent rdfs:label ?continentLabel.
        OPTIONAL {  ?s wdt:P106 ?occupation.
                    # ?occupation rdfs:label ?occupationLabel.}
        OPTIONAL {  ?s wdt:P101 ?field.
                    # ?field rdfs:label ?fieldLabel.}

        ## Excluding Australia and Oceania insular
        # Eurasia : wd:Q5401 
        FILTER ( ?continent NOT IN ( wd:Q3960, wd:Q538))
          }
}
GROUP BY ?s
FILTER 100

"""

# %%
### Executer la requête avec les fonctions de la librairie locale
qr = spqf.get_json_sparql_result(endpoint,query)
# Out:
# <urlopen error [Errno 60] Operation timed out>

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# 0
# []

# %%
### Créer un DataFrame à partir du résultat
df_p = pd.DataFrame(r)
df_p.columns = ['personUri', 'personLabel', 'birthYear', 'gender', 'countries', 'continents', 'occupations', 'fields']
df_p.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 3
#       1 ### Créer un DataFrame à partir du résultat
#       2 df_p = pd.DataFrame(r)
# ----> 3 df_p.columns = ['personUri', 'personLabel', 'birthYear', 'gender', 'countries', 'continents', 'occupations', 'fields']
#       4 df_p.head()
#
# File ~/Desktop/University/Bachelor 2/Humanités numeriques/poets/novelists/myenv/lib/python3.12/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/Desktop/University/Bachelor 2/Humanités numeriques/poets/novelists/myenv/lib/python3.12/site-packages/pandas/core/generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File ~/Desktop/University/Bachelor 2/Humanités numeriques/poets/novelists/myenv/lib/python3.12/site-packages/pandas/core/internals/managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~/Desktop/University/Bachelor 2/Humanités numeriques/poets/novelists/myenv/lib/python3.12/site-packages/pandas/core/internals/base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 8 elements

# %%
## transformer les années en entiers
df_p.birthYear = df_p.birthYear.apply(lambda x : int(x))

# %%
### Inspecter la structure du dataframe
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23684 entries, 0 to 23683
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   personUri    23684 non-null  object
#  1   personLabel  23684 non-null  object
#  2   birthYear    23684 non-null  int64
#  3   gender       23684 non-null  object
#  4   countries    23684 non-null  object
#  5   continents   23684 non-null  object
#  6   occupations  23684 non-null  object
#  7   fields       23684 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.4+ MB

# %%
### Store to CSV
f_path = 'data/df_continent_occupations_fields_20250406.csv'
df_p.to_csv(f_path)

# %% [markdown]
# ## Coder les continents et afficher leur distribution

# %%
### Inspecter les données
print(df_p.iloc[ :5 , :].continents)
# Out:
# 0           Europe, Asia
# 1    North America, Asia
# 2                 Europe
# 3    North America, Asia
# 4                 Europe
# Name: continents, dtype: object

# %%
### Regrouper et compter
df_contCode = df_p.groupby('continents').size()
df_contCode.columns=['effectif']
df_contCode = pd.DataFrame(df_contCode.sort_values( ascending = False))
#df_contCode.reset_index(inplace=True)
print(df_contCode.head(10))
# Out:
#                                           0
# continents
# Europe                                13343
# North America                          4248
# Asia                                   2055
# Europe, Asia                           1582
# South America                           389
# North America, Europe                   319
# Oceania                                 288
# Europe, Asia, North America, Eurasia    265
# Asia, Europe                            246
# Africa                                  139

# %%
### Créer une fonction de codage
def codeContinents(continents):
    
    if 'Europe, Asia' in continents:
        output = 'Eurasia'    
    elif 'Europe' in continents:
        output = 'Europe'
    elif 'Africa' in continents:
        output = 'Africa'
    elif 'Oceania' in continents:
        output = 'Oceania'
    ## Issue with Russia, Russian Empire, Wikidata not consistent    
    elif 'Eurasia' in continents:
        output = 'Eurasia'
    elif 'North America' in continents:
        output = 'NorthAmerica'   
    elif 'Asia' in continents:
        output = 'Asia'
    elif 'South America' in continents:
        output = 'SouthAmerica' 
    else:
        output = 'Missing'                 
    return output

# %%
### Tester la fonction
print(codeContinents('Oceania, North America, Africa'))
# Out:
# Africa

# %%
### On ajoute une nouvelle colonne 'contCode' et y on met pour chaque ligne le résultat de la fonction
df_p['contCode'] = df_p.apply(lambda x: codeContinents(x['continents']), axis=1)
df_p.head(3)
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
#
#    gender              countries           continents  \
# 0    male  Ukraine, Soviet Union         Europe, Asia
# 1  female   United States, India  North America, Asia
# 2    male         United Kingdom               Europe
#
#                 occupations fields      contCode
# 0                 physicist              Eurasia
# 1   physicist, biophysicist         NorthAmerica
# 2  physicist, mathematician               Europe

# %%
### Regrouper et compter
df_contCode = df_p.groupby('contCode').size()
df_contCode = pd.DataFrame(df_contCode.sort_values(ascending = True))
#df_contCode.reset_index(inplace=True)
df_contCode.columns=['effectif']
print(df_contCode)
# Out:
#               effectif
# contCode
# Africa             150
# Oceania            302
# SouthAmerica       389
# Asia              2055
# Eurasia           2121
# NorthAmerica      4353
# Europe           14314

# %%
### How to handle data about Russians
df_p[df_p.countries.str.contains('Russi')].head(7)
# Out:
#                                    personUri                     personLabel  \
# 12  http://www.wikidata.org/entity/Q60167219               Yuri Golembiovsky
# 20  http://www.wikidata.org/entity/Q52195429  Konstantin Iosifovich Gringauz
# 32   http://www.wikidata.org/entity/Q4095524                  Pyotr Boyarsky
# 42  http://www.wikidata.org/entity/Q29363866                Joseph Poliakoff
# 45  http://www.wikidata.org/entity/Q12103107                  Amos Diachenko
# 66  http://www.wikidata.org/entity/Q92949648                       Q92949648
# 84  http://www.wikidata.org/entity/Q60832387                   Dmitry Mishin
#
#     birthYear gender                                          countries  \
# 12       1937   male                                             Russia
# 20       1918   male                               Russia, Soviet Union
# 32       1943   male                               Soviet Union, Russia
# 42       1873   male  Russian Empire, United Kingdom, United Kingdom...
# 45       1814   male                                     Russian Empire
# 66       1909   male                               Soviet Union, Russia
# 84       1919   male                Soviet Union, Russia, Russian State
#
#                         continents  \
# 12                          Europe
# 20                    Europe, Asia
# 32                    Europe, Asia
# 42  North America, Eurasia, Europe
# 45          North America, Eurasia
# 66                    Europe, Asia
# 84           Europe, Asia, Eurasia
#
#                                           occupations  \
# 12                       physicist, teacher, engineer
# 20                                          physicist
# 32  executive, historian, writer, geographer, edit...
# 42                      inventor, physicist, engineer
# 45                          astronomer, mathematician
# 66                      university teacher, physicist
# 84                      university teacher, physicist
#
#                                                fields contCode
# 12                                                      Europe
# 20                       astrophysics, plasma physics  Eurasia
# 32  research expedition, polar expedition, polar r...  Eurasia
# 42                                                      Europe
# 45  astronomy, theory of differential equations, m...  Eurasia
# 66                                        mathematics  Eurasia
# 84                                            physics  Eurasia

# %%
 
### Regrouper et compter les personnes issues de Russie
df_contCode = df_p[df_p.countries.str.contains('ussi')].groupby('contCode').size()
df_contCode = pd.DataFrame(df_contCode.sort_values(ascending = True))
#df_contCode.reset_index(inplace=True)
df_contCode.columns=['effectif']
print(df_contCode)
# Out:
#           effectif
# contCode
# Europe         653
# Eurasia       1441

# %%
### On ajoute une nouvelle colonne et y on met pour chaque ligne le résultat de la fonction
df_p.iloc[ 97:101 , : ]
# Out:
#                                      personUri               personLabel  \
# 97     http://www.wikidata.org/entity/Q2573136  Wilhelm Heinrich Heraeus
# 98     http://www.wikidata.org/entity/Q1730238   Karl Albert Hasselbalch
# 99     http://www.wikidata.org/entity/Q4131361            Andrey Gagarin
# 100  http://www.wikidata.org/entity/Q107844507             Stefania Gori
#
#      birthYear  gender                                          countries  \
# 97        1900    male                                            Germany
# 98        1874    male                                 Kingdom of Denmark
# 99        1856    male  Russian Soviet Federative Socialist Republic, ...
# 100       1983  female                                              Italy
#
#                  continents                         occupations   fields  \
# 97                   Europe    physicist, entrepreneur, chemist
# 98                   Europe                  physicist, chemist
# 99   Eurasia, North America  engineer, mathematician, pedagogue  physics
# 100                  Europe                           physicist
#
#     contCode
# 97    Europe
# 98    Europe
# 99   Eurasia
# 100   Europe

# %%
# Noter la personne index 116, František Doutlík trouvé grâce à la propriété 'field'
df_p.iloc[ 111:118 :  ]
# Out:
#                                      personUri                personLabel  \
# 111    http://www.wikidata.org/entity/Q4511457  Luise Meyer-Schützmeister
# 112   http://www.wikidata.org/entity/Q57024819             Hannes Pichler
# 113  http://www.wikidata.org/entity/Q126718262                  Zhou Lian
# 114    http://www.wikidata.org/entity/Q7085825            Ole Colbjørnsen
# 115   http://www.wikidata.org/entity/Q59624350            Alberto Carlini
# 116   http://www.wikidata.org/entity/Q95361999          František Doutlík
# 117   http://www.wikidata.org/entity/Q17119374               Eliza Wilbur
#
#      birthYear  gender                   countries     continents  \
# 111       1915  female                     Germany         Europe
# 112       1986    male              Italy, Austria         Europe
# 113       1940    male  People's Republic of China           Asia
# 114       1897    male                      Norway         Europe
# 115       1965    male                       Italy         Europe
# 116       1880    male              Czechoslovakia         Europe
# 117       1851  female               United States  North America
#
#                                       occupations  \
# 111                  physicist, nuclear physicist
# 112                         researcher, physicist
# 113                         researcher, physicist
# 114  physicist, journalist, politician, economist
# 115                                     physicist
# 116                 teacher, chronicler, musician
# 117                          inventor, astronomer
#
#                             fields      contCode
# 111                                       Europe
# 112                                       Europe
# 113                                         Asia
# 114                                       Europe
# 115                                       Europe
# 116  astronomy, educational system        Europe
# 117                                 NorthAmerica

# %%
### Personnes trouvées grâce à leur champ, 'field'
# https://stackoverflow.com/questions/21055068/reversal-of-string-contains-in-python-pandas
dff = df_p[~(df_p.occupations.str.contains("astronomer|physicist"))]
print('Effectif: ', len(dff), '\n')
print(dff.head(2).personUri)
dff.head()
# Out:
# Effectif:  436
#
# 94      http://www.wikidata.org/entity/Q72055
# 99    http://www.wikidata.org/entity/Q4131361
# Name: personUri, dtype: object
#                                      personUri        personLabel  birthYear  \
# 94       http://www.wikidata.org/entity/Q72055   Albrecht Wellmer       1933
# 99     http://www.wikidata.org/entity/Q4131361     Andrey Gagarin       1856
# 116   http://www.wikidata.org/entity/Q95361999  František Doutlík       1880
# 128    http://www.wikidata.org/entity/Q4444381   Vladimir Strunin       1953
# 154  http://www.wikidata.org/entity/Q114191385         Q114191385       1946
#
#     gender                                          countries  \
# 94    male                                            Germany
# 99    male  Russian Soviet Federative Socialist Republic, ...
# 116   male                                     Czechoslovakia
# 128   male                                             Russia
# 154   male                              Soviet Union, Belarus
#
#                  continents                                   occupations  \
# 94                   Europe  sociologist, university teacher, philosopher
# 99   Eurasia, North America            engineer, mathematician, pedagogue
# 116                  Europe                 teacher, chronicler, musician
# 128                  Europe                                     scientist
# 154            Europe, Asia                 scientist, university teacher
#
#                             fields contCode
# 94            mathematics, physics   Europe
# 99                         physics  Eurasia
# 116  astronomy, educational system   Europe
# 128                        physics   Europe
# 154                optics, physics  Eurasia

# %% [markdown]
# ### Distribution des continents: représentation graphique

# %%
### Regrouper et compter
df_contCode = df_p.groupby('contCode').size()
df_contCode = pd.DataFrame(df_contCode.sort_values(ascending = True))
#df_contCode.reset_index(inplace=True)
df_contCode.columns=['effectif']

df_contCode['frequence'] = (100 * df_contCode['effectif'] \
                                   / df_contCode['effectif'].sum()).round(2)
df_contCode
# Out:
#               effectif  frequence
# contCode
# Africa             150       0.63
# Oceania            302       1.28
# SouthAmerica       389       1.64
# Asia              2055       8.68
# Eurasia           2121       8.96
# NorthAmerica      4353      18.38
# Europe           14314      60.44

# %%
ljt = pd.DataFrame(df_contCode['frequence'].sort_values(ascending=False)).T
ljt
# Out:
# contCode   Europe  NorthAmerica  Eurasia  Asia  SouthAmerica  Oceania  Africa
# frequence   60.44         18.38     8.96  8.68          1.64     1.28    0.63

# %%
### Définir les couleurs en fonction des continents
# Noter que cette liste des couleurs et continents
# doit être adaptée à l'ordre de tri des données 
# dans le graphique
col_palette = [
    "#DCDCDC",  # Gainsboro : Europe
    "#cd5c5c",  # Indian Red : NorthAmerica
    "#F4A261",  # Light Coral: Asia
    "#F6E58D",  # Light Yellow :SouthAmerica
    "#B2E0B2",  # Light Green : Oceania
    "#E3D4AD",  # Desert Sand : Eurasia
    "#A3C1DA",  # Light Blue : Africa    

]

# %%
### Pandas plot reference
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html
## Barplots
# https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/

fig = ljt.plot(kind='barh', stacked=True, figsize=(15,3), color=col_palette, width=0.2, xlim=[0,100])

# %% [markdown]
# ### Codage par période de vingt-cinq ans

# %%
### Créer une liste d'années pour séparer en périodes de 25 ans
# noter que la dernière année sera exclue, 
# elle donc doit être supérieure à la valeur maximale 
l_25 = list(range(1751, 2025, 25))
print(l_25[:5],l_25[-5:], len(l_25)-1)
# Out:
# [1751, 1776, 1801, 1826, 1851] [1901, 1926, 1951, 1976, 2001] 10

# %%
### Transformer les années de naissance en entiers
df_p.birthYear = df_p.birthYear.apply(lambda x : int(x))

# %%
### fonction pd.cut : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html
# On ajoute une nouvelle colonne qui contient la période sur la base de la liste précédente
# et de la valeur de l'année

df_p['per_25'] = pd.cut(df_p['birthYear'], l_25, right=False)

### Transformer le code ajouté pour qu'il soit plus lisible
# noter qu'on a arrondi les valeurs
df_p['per_25'] = df_p['per_25'].apply(lambda x : str(int(x.left))+'-'+ str(int(x.right)-1))

# Inspection
df_p.head(3)
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
#
#    gender              countries           continents  \
# 0    male  Ukraine, Soviet Union         Europe, Asia
# 1  female   United States, India  North America, Asia
# 2    male         United Kingdom               Europe
#
#                 occupations fields      contCode     per_25
# 0                 physicist              Eurasia  1926-1950
# 1   physicist, biophysicist         NorthAmerica  1951-1975
# 2  physicist, mathematician               Europe  1901-1925

# %%
### distribution des naissances par périodes de 25 ans
naissances_per = df_p.groupby(by='per_25', observed=True).size()
print(naissances_per)
# Out:
# per_25
# 1751-1775     252
# 1776-1800     328
# 1801-1825     534
# 1826-1850     811
# 1851-1875    1312
# 1876-1900    1918
# 1901-1925    4215
# 1926-1950    8133
# 1951-1975    4959
# 1976-2000    1222
# dtype: int64

# %% [markdown]
# ### Comparer période et continent

# %%
### Tableau de contingence
X = "contCode"
Y = "per_25"  # "0"

ddf = df_p[[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
ddf
# Out:
# contCode   Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  SouthAmerica  \
# per_25
# 1751-1775       0     8       10     229             4        0             1
# 1776-1800       1     3       18     286            17        2             1
# 1801-1825       2     7       28     445            47        2             3
# 1826-1850       2     6       63     630            97        8             5
# 1851-1875       5    24      105     940           201       25            12
# 1876-1900       7    83      135    1335           329       17            12
# 1901-1925      19   366      498    2160          1041       72            59
# 1926-1950      40   885     1000    4348          1606      106           148
# 1951-1975      46   565      253    3109           816       59           111
# 1976-2000      28   108       11     832           195       11            37
# Total         150  2055     2121   14314          4353      302           389
#
# contCode   Total
# per_25
# 1751-1775    252
# 1776-1800    328
# 1801-1825    534
# 1826-1850    811
# 1851-1875   1312
# 1876-1900   1918
# 1901-1925   4215
# 1926-1950   8133
# 1951-1975   4959
# 1976-2000   1222
# Total      23684

# %%
### Modifiy column order
print(ddf.columns.to_list())
ddf = ddf[['Europe', 'Eurasia',  'NorthAmerica', 'Asia', 'Africa', 'Oceania', 'SouthAmerica', 'Total']]
ddf
# Out:
# ['Africa', 'Asia', 'Eurasia', 'Europe', 'NorthAmerica', 'Oceania', 'SouthAmerica', 'Total']
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica  \
# per_25
# 1751-1775     229       10             4     8       0        0             1
# 1776-1800     286       18            17     3       1        2             1
# 1801-1825     445       28            47     7       2        2             3
# 1826-1850     630       63            97     6       2        8             5
# 1851-1875     940      105           201    24       5       25            12
# 1876-1900    1335      135           329    83       7       17            12
# 1901-1925    2160      498          1041   366      19       72            59
# 1926-1950    4348     1000          1606   885      40      106           148
# 1951-1975    3109      253           816   565      46       59           111
# 1976-2000     832       11           195   108      28       11            37
# Total       14314     2121          4353  2055     150      302           389
#
# contCode   Total
# per_25
# 1751-1775    252
# 1776-1800    328
# 1801-1825    534
# 1826-1850    811
# 1851-1875   1312
# 1876-1900   1918
# 1901-1925   4215
# 1926-1950   8133
# 1951-1975   4959
# 1976-2000   1222
# Total      23684

# %%
### Adapter à l'ordre des colonnes
col_palette_1 = [
    "#DCDCDC",  # Gainsboro : Europe
    "#E3D4AD",  # Desert Sand : Eurasia
    "#cd5c5c",  # Indian Red : NorthAmerica
    "#F4A261",  # Light Coral : Asia
    "#A3C1DA",  # Light Blue : Africa
    "#B2E0B2",  # Light Green : Oceania
    "#F6E58D",  # Light Yellow : SouthAmerica
    
]

# %%
### Représenter l'évolution de la distribution dans le temps par continent
#  Documentation
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html

data = ddf.iloc[:-1,:-1]

ax = data.plot.bar(stacked=True, rot=70, fontsize=9, figsize=(10,8), 
                     color=col_palette_1)
plt.title('Distribution des naissances par génération et continent')

## https://stackoverflow.com/questions/71320380/add-only-the-total-values-on-top-of-stacked-bars
ax.bar_label(ax.containers[-1])

plt.show()

# %% [markdown]
# ## Analyse bivariée: périodes, continents
#
#
#
# On observe un fort déséquilibre entre les périodes et les continents. On peut présenter ce fait, par exemple en relevant le développement des États Unis et de la Russie (Eurasie) dès le milieu du 19e siècle. Mais on ne peut pas utiliser les données comme telles pour une analyse, il faudra restreindre l'analyse à la partie du tableau pour laquelle les effectis sont suffisants.

# %%
ddf
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica  \
# per_25
# 1751-1775     229       10             4     8       0        0             1
# 1776-1800     286       18            17     3       1        2             1
# 1801-1825     445       28            47     7       2        2             3
# 1826-1850     630       63            97     6       2        8             5
# 1851-1875     940      105           201    24       5       25            12
# 1876-1900    1335      135           329    83       7       17            12
# 1901-1925    2160      498          1041   366      19       72            59
# 1926-1950    4348     1000          1606   885      40      106           148
# 1951-1975    3109      253           816   565      46       59           111
# 1976-2000     832       11           195   108      28       11            37
# Total       14314     2121          4353  2055     150      302           389
#
# contCode   Total
# per_25
# 1751-1775    252
# 1776-1800    328
# 1801-1825    534
# 1826-1850    811
# 1851-1875   1312
# 1876-1900   1918
# 1901-1925   4215
# 1926-1950   8133
# 1951-1975   4959
# 1976-2000   1222
# Total      23684

# %%
### Production du tableau à analyser
## Noter que pour que l'analyse soit significative en 
# termes de Chi-2 il faudrait partir de la ligne quatre
# Aussi, la dernière ligne est probablement incomplète
# en termes de génération
D = ddf.iloc[3:10,:-1].copy(deep=True)
D
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850     630       63            97     6       2        8             5
# 1851-1875     940      105           201    24       5       25            12
# 1876-1900    1335      135           329    83       7       17            12
# 1901-1925    2160      498          1041   366      19       72            59
# 1926-1950    4348     1000          1606   885      40      106           148
# 1951-1975    3109      253           816   565      46       59           111
# 1976-2000     832       11           195   108      28       11            37

# %%
## Nombre de modalités ligne
K = D.shape[0]
## Nombre de modalités colonnes
L = D.shape[1]
# Effectif total
n = np.sum(D.values)
# Nombre max. de facteur
Hmax = np.min([K-1,L-1])

print('Dimensions: (', K, ',', L, '), effectif:', n, ', nombre max. facteurs:', Hmax)
# Out:
# Dimensions: ( 7 , 7 ), effectif: 22570 , nombre max. facteurs: 6

# %%
### Valeurs produites par la fonction de la librairie 'stats'
statistic, p, dof, expected = stats.chi2_contingency(D)

print('Chi2 :', statistic.round(2), ', dof :',dof)
print('p-value :', p)


print('phi2 = inertie (variance totale) :', statistic/n)


### Tableau à l'indépendance
dfe = round(pd.DataFrame(expected),4)

### Coéfficient de Cramer
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html

vc = stats.contingency.association(D, method='cramer')
print('Cramer: ', vc)
# Out:
# Chi2 : 1053.38 , dof : 36
# p-value : 9.796450821987583e-198
# phi2 = inertie (variance totale) : 0.04667167942478499
# Cramer:  0.08819644685283055

# %%
### Situation à l'indépendance

indep = pd.DataFrame(expected)
indep.columns = D.columns
indep.index = D.index
indep.round(0).astype(int)
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850     480       74           154    73       5       11            14
# 1851-1875     776      120           249   118       9       17            22
# 1876-1900    1135      175           364   173      12       25            33
# 1901-1925    2494      386           800   380      27       56            72
# 1926-1950    4812      744          1544   734      53      107           138
# 1951-1975    2934      454           941   448      32       65            84
# 1976-2000     723      112           232   110       8       16            21

# %%
D
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850     630       63            97     6       2        8             5
# 1851-1875     940      105           201    24       5       25            12
# 1876-1900    1335      135           329    83       7       17            12
# 1901-1925    2160      498          1041   366      19       72            59
# 1926-1950    4348     1000          1606   885      40      106           148
# 1951-1975    3109      253           816   565      46       59           111
# 1976-2000     832       11           195   108      28       11            37

# %%
### Écart à l'indépendance:
# différence en effectifs entre le théorique et l'observé
#  Valeurs arrondies
### Doc. :
#   Bennani, p.30
#  https://openclassrooms.com/fr/courses/4525266-decrivez-et-nettoyez-votre-jeu-de-donnees/4775616-analysez-deux-variables-qualitatives-avec-le-chi-2
ecarts = (D-indep)
## Attention : arrondi aux entiers dans l'affichage
print(ecarts.round(0).astype(int))
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850     150      -11           -57   -67      -3       -3            -9
# 1851-1875     164      -15           -48   -94      -4        8           -10
# 1876-1900     200      -40           -35   -90      -5       -8           -21
# 1901-1925    -334      112           241   -14      -8       16           -13
# 1926-1950    -464      256            62   151     -13       -1            10
# 1951-1975     175     -201          -125   117      14       -6            27
# 1976-2000     109     -101           -37    -2      20       -5            16

# %%
### Résidus pondérés (avec le signe)
### Doc. :
#   Rakotomalala, p.240
residus_ponderes = (round((D-indep)/np.sqrt(indep),2))
residus_ponderes
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850    6.85    -1.30         -4.59 -7.85   -1.43    -0.83         -2.37
# 1851-1875    5.88    -1.37         -3.05 -8.68   -1.21     1.84         -2.18
# 1876-1900    5.94    -3.06         -1.84 -6.85   -1.55    -1.65         -3.61
# 1901-1925   -6.69     5.72          8.51 -0.74   -1.61     2.19         -1.50
# 1926-1950   -6.69     9.38          1.58  5.57   -1.78    -0.13          0.82
# 1951-1975    3.23    -9.42         -4.09  5.55    2.41    -0.80          2.90
# 1976-2000    4.05    -9.53         -2.43 -0.22    7.10    -1.28          3.55

# %%
### Résidus pondérés
tableau = residus_ponderes

fig, ax = plt.subplots(figsize=(9,6))         
# Sample figsize in inches
g = sns.heatmap(tableau, annot=tableau, cmap="coolwarm", linewidths=.5, ax=ax)
labels = tableau.index
p = g.set_yticklabels(labels, rotation=30)

plt.show()

# %% [markdown]
# ### En excluant l'Europe ou choisissant les pays

# %%
print(D.columns.to_list())
D.iloc[ : , 1:]
# Out:
# ['Europe', 'Eurasia', 'NorthAmerica', 'Asia', 'Africa', 'Oceania', 'SouthAmerica']
# contCode   Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850       63            97     6       2        8             5
# 1851-1875      105           201    24       5       25            12
# 1876-1900      135           329    83       7       17            12
# 1901-1925      498          1041   366      19       72            59
# 1926-1950     1000          1606   885      40      106           148
# 1951-1975      253           816   565      46       59           111
# 1976-2000       11           195   108      28       11            37

# %%
### Valeurs produites par la fonction de la librairie 'stats'
statistic, p, dof, expected = stats.chi2_contingency(D.iloc[ : , 1:])

print('Chi2 :', statistic.round(2), ', dof :',dof)
print('p-value :', p)


print('phi2 = inertie (variance totale) :', statistic/n)


### Tableau à l'indépendance
dfe = round(pd.DataFrame(expected),4)

### Coéfficient de Cramer
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html

vc = stats.contingency.association(D.iloc[ : , 1:], method='cramer')
print('Cramer: ', vc)
# Out:
# Chi2 : 568.06 , dof : 30
# p-value : 1.1881461634142798e-100
# phi2 = inertie (variance totale) : 0.025169028853236415
# Cramer:  0.11103062222450762

# %%
D[['Europe', 'Asia', 'Eurasia', 'NorthAmerica', 'SouthAmerica']]
# Out:
# contCode   Europe  Asia  Eurasia  NorthAmerica  SouthAmerica
# per_25
# 1826-1850     630     6       63            97             5
# 1851-1875     940    24      105           201            12
# 1876-1900    1335    83      135           329            12
# 1901-1925    2160   366      498          1041            59
# 1926-1950    4348   885     1000          1606           148
# 1951-1975    3109   565      253           816           111
# 1976-2000     832   108       11           195            37

# %%
### Valeurs produites par la fonction de la librairie 'stats'
statistic, p, dof, expected = stats.chi2_contingency(D[['Europe', 'Eurasia']])

print('Chi2 :', statistic.round(2), ', dof :',dof)
print('p-value :', p)


print('phi2 = inertie (variance totale) :', statistic/n)


### Tableau à l'indépendance
dfe = round(pd.DataFrame(expected),4)

### Coéfficient de Cramer
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html

vc = stats.contingency.association(D[['Europe', 'Eurasia']], method='cramer')
print('Cramer: ', vc)
# Out:
# Chi2 : 444.8 , dof : 6
# p-value : 6.462563218564027e-93
# phi2 = inertie (variance totale) : 0.019707503847864394
# Cramer:  0.16984528117479006

# %% [markdown]
# ## Continent et genre

# %%
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                      countries           continents  \
# 0    male          Ukraine, Soviet Union         Europe, Asia
# 1  female           United States, India  North America, Asia
# 2    male                 United Kingdom               Europe
# 3    male  United States, Israel, Canada  North America, Asia
# 4    male                 Czechoslovakia               Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             academic, physicist
# 4  physicist, chemist, pharmacist
#
#                                            fields      contCode     per_25
# 0                                                       Eurasia  1926-1950
# 1                                                  NorthAmerica  1951-1975
# 2                                                        Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity  NorthAmerica  1901-1925
# 4                                                        Europe  1926-1950

# %%
### Tableau de contingence
X = "contCode"
Y = "gender"  # "0"

ddgc = df_p[df_p.gender.isin(['female', 'male'])][[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
ddgc
# Out:
# contCode  Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  SouthAmerica  \
# gender
# female        36   146       90    1236           495       32            87
# male         114  1906     2031   13074          3852      268           302
# Total        150  2052     2121   14310          4347      300           389
#
# contCode  Total
# gender
# female     2122
# male      21547
# Total     23669

# %% [markdown]
# ### Créer la fonction

# %%
def bivariee_stats(D):
    ### Valeurs produites par la fonction de la librairie 'stats'
    statistic, p, dof, expected = stats.chi2_contingency(D)

    print('Chi2 :', statistic.round(2), ', dof :',dof)
    print('p-value :', p)


    print('phi2 = inertie (variance totale) :', statistic/n)


    ### Tableau à l'indépendance
    dfe = round(pd.DataFrame(expected),4)

    ### Coéfficient de Cramer
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html

    vc = stats.contingency.association(D, method='cramer')
    print('Cramer: ', vc)

    ### Situation à l'indépendance
    indep = pd.DataFrame(expected)
    indep.columns = D.columns
    indep.index = D.index

    ### Résidus pondérés (avec le signe)
    ### Doc. :
    #   Rakotomalala, p.240
    residus_ponderes = (round((D-indep)/np.sqrt(indep),2))
    ### Résidus pondérés
    tableau = residus_ponderes

    fig, ax = plt.subplots(figsize=(9,3))         
    # Sample figsize in inches
    g = sns.heatmap(tableau, annot=tableau, cmap="coolwarm", linewidths=.5, ax=ax)
    xlabels = tableau.columns
    px = g.set_xticklabels(xlabels, rotation=60, size=8, 
                           ha='right', rotation_mode='anchor')
    ylabels = tableau.index
    py = g.set_yticklabels(ylabels, rotation=20, size=8)
    
    plt.show()

# %%
### Production du tableau à analyser
## Noter que pour que l'analyse soit significative en 
# termes de Chi-2 il faudrait partir de la ligne quatre
# Aussi, la dernière ligne est probablement incomplète
# en termes de génération
D = ddgc.iloc[:-1,:-1].copy(deep=True)
D
# Out:
# contCode  Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  SouthAmerica
# gender
# female        36   146       90    1236           495       32            87
# male         114  1906     2031   13074          3852      268           302

# %%
bivariee_stats(D)
# Out:
# Chi2 : 227.87 , dof : 6
# p-value : 2.1829552552815577e-46
# phi2 = inertie (variance totale) : 0.01009604582889911
# Cramer:  0.09811863128801099

# %% [markdown]
# ### Genre et continent par époque

# %%
df_p['genre_cont'] = df_p.apply(lambda x: x.contCode + '_' + x.gender, axis=1)
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                      countries           continents  \
# 0    male          Ukraine, Soviet Union         Europe, Asia
# 1  female           United States, India  North America, Asia
# 2    male                 United Kingdom               Europe
# 3    male  United States, Israel, Canada  North America, Asia
# 4    male                 Czechoslovakia               Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             academic, physicist
# 4  physicist, chemist, pharmacist
#
#                                            fields      contCode     per_25  \
# 0                                                       Eurasia  1926-1950
# 1                                                  NorthAmerica  1951-1975
# 2                                                        Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity  NorthAmerica  1901-1925
# 4                                                        Europe  1926-1950
#
#             genre_cont
# 0         Eurasia_male
# 1  NorthAmerica_female
# 2          Europe_male
# 3    NorthAmerica_male
# 4          Europe_male

# %%
### Tableau de contingence
X = "genre_cont"
Y = "per_25"  # "0"

ddgcp = df_p[df_p.gender.isin(['female', 'male'])][[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
ddgcp
# Out:
# genre_cont  Africa_female  Africa_male  Asia_female  Asia_male  \
# per_25
# 1751-1775               0            0            1          7
# 1776-1800               0            1            0          3
# 1801-1825               0            2            0          7
# 1826-1850               0            2            0          6
# 1851-1875               0            5            0         24
# 1876-1900               0            7            0         83
# 1901-1925               3           16           24        341
# 1926-1950               4           36           41        843
# 1951-1975              14           32           54        511
# 1976-2000              15           13           26         81
# Total                  36          114          146       1906
#
# genre_cont  Eurasia_female  Eurasia_male  Europe_female  Europe_male  \
# per_25
# 1751-1775                0            10              4          225
# 1776-1800                0            18              6          280
# 1801-1825                0            28              3          442
# 1826-1850                0            63             11          619
# 1851-1875                2           103             33          907
# 1876-1900               11           124             92         1243
# 1901-1925               23           475            158         2002
# 1926-1950               37           963            295         4052
# 1951-1975               15           238            424         2683
# 1976-2000                2             9            210          621
# Total                   90          2031           1236        13074
#
# genre_cont  NorthAmerica_female  NorthAmerica_male  Oceania_female  \
# per_25
# 1751-1775                     0                  4               0
# 1776-1800                     0                 17               0
# 1801-1825                     4                 43               0
# 1826-1850                     7                 90               0
# 1851-1875                    23                178               2
# 1876-1900                    45                284               1
# 1901-1925                    75                966               6
# 1926-1950                   120               1486               6
# 1951-1975                   158                656              12
# 1976-2000                    63                128               5
# Total                       495               3852              32
#
# genre_cont  Oceania_male  SouthAmerica_female  SouthAmerica_male  Total
# per_25
# 1751-1775              0                    0                  1    252
# 1776-1800              2                    0                  1    328
# 1801-1825              2                    0                  3    534
# 1826-1850              8                    0                  5    811
# 1851-1875             23                    0                 12   1312
# 1876-1900             16                    0                 12   1918
# 1901-1925             66                   13                 46   4214
# 1926-1950             99                   26                122   8130
# 1951-1975             46                   36                 75   4954
# 1976-2000              6                   12                 25   1216
# Total                268                   87                302  23669

# %%
### Limiter à la période significative, 20 siècle
D = ddgcp.iloc[6:-1,:-1].copy(deep=True)
D
# Out:
# genre_cont  Africa_female  Africa_male  Asia_female  Asia_male  \
# per_25
# 1901-1925               3           16           24        341
# 1926-1950               4           36           41        843
# 1951-1975              14           32           54        511
# 1976-2000              15           13           26         81
#
# genre_cont  Eurasia_female  Eurasia_male  Europe_female  Europe_male  \
# per_25
# 1901-1925               23           475            158         2002
# 1926-1950               37           963            295         4052
# 1951-1975               15           238            424         2683
# 1976-2000                2             9            210          621
#
# genre_cont  NorthAmerica_female  NorthAmerica_male  Oceania_female  \
# per_25
# 1901-1925                    75                966               6
# 1926-1950                   120               1486               6
# 1951-1975                   158                656              12
# 1976-2000                    63                128               5
#
# genre_cont  Oceania_male  SouthAmerica_female  SouthAmerica_male
# per_25
# 1901-1925             66                   13                 46
# 1926-1950             99                   26                122
# 1951-1975             46                   36                 75
# 1976-2000              6                   12                 25

# %%
## Appliquer la fonction
bivariee_stats(D)
# Out:
# Chi2 : 1209.8 , dof : 39
# p-value : 2.1232955134234553e-228
# phi2 = inertie (variance totale) : 0.05360212864441971
# Cramer:  0.14758629855670627

# %% [markdown]
# #### Explorer les résultats et commenter

# %%
df_pef = df_p[df_p['genre_cont'] == 'Europe_female']
print(len(df_pef))
# Out:
# 1236

# %%
print(df_pef.groupby(by='countries', observed=True).size().sort_values(ascending=False).head(10))
# Out:
# countries
# France            144
# Germany           129
# Poland            105
# United Kingdom     88
# Italy              88
# Spain              71
# Austria            44
# Sweden             35
# Finland            27
# Slovenia           25
# dtype: int64

# %%
print(df_pef[df_pef.per_25 == '1976-2000'].groupby(by='countries', observed=True).size().sort_values(ascending=False).head(10))
# Out:
# countries
# Germany           27
# Italy             27
# United Kingdom    20
# Spain             18
# France            15
# Poland            13
# Russia             8
# Hungary            7
# Finland            7
# Sweden             7
# dtype: int64

# %%
fff = df_pef[(df_pef.per_25 == '1976-2000') & (df_pef.countries.str.contains('Germany'))]
print(len(fff))
fff.head()
# Out:
# 34
#                                       personUri       personLabel  birthYear  \
# 1623   http://www.wikidata.org/entity/Q60143297     Katerina Falk       1984
# 2391   http://www.wikidata.org/entity/Q96691414  Olena Karacheban       1990
# 4644   http://www.wikidata.org/entity/Q50923671       Kathy Ludge       1976
# 4877  http://www.wikidata.org/entity/Q125267067     Dorit Glawion       1987
# 5763  http://www.wikidata.org/entity/Q117234388  Anna Franckowiak       1983
#
#       gender                countries continents  \
# 1623  female  Czech Republic, Germany     Europe
# 2391  female                  Germany     Europe
# 4644  female                  Germany     Europe
# 4877  female                  Germany     Europe
# 5763  female                  Germany     Europe
#
#                                     occupations  \
# 1623                       scientist, physicist
# 2391                      researcher, physicist
# 4644              physicist, university teacher
# 4877                     researcher, astronomer
# 5763  university teacher, physicist, researcher
#
#                                                  fields contCode     per_25  \
# 1623  plasma, popular science, astrophysics, laser, ...   Europe  1976-2000
# 2391                                                      Europe  1976-2000
# 4644                                                      Europe  1976-2000
# 4877                                                      Europe  1976-2000
# 5763           neutrino, astrophysics, cosmic radiation   Europe  1976-2000
#
#          genre_cont
# 1623  Europe_female
# 2391  Europe_female
# 4644  Europe_female
# 4877  Europe_female
# 5763  Europe_female

# %% [markdown]
# ## Continent et discipline

# %%
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                      countries           continents  \
# 0    male          Ukraine, Soviet Union         Europe, Asia
# 1  female           United States, India  North America, Asia
# 2    male                 United Kingdom               Europe
# 3    male  United States, Israel, Canada  North America, Asia
# 4    male                 Czechoslovakia               Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             academic, physicist
# 4  physicist, chemist, pharmacist
#
#                                            fields      contCode     per_25  \
# 0                                                       Eurasia  1926-1950
# 1                                                  NorthAmerica  1951-1975
# 2                                                        Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity  NorthAmerica  1901-1925
# 4                                                        Europe  1926-1950
#
#             genre_cont
# 0         Eurasia_male
# 1  NorthAmerica_female
# 2          Europe_male
# 3    NorthAmerica_male
# 4          Europe_male

# %%
def code_discipline(col1, col2):
    if  'astronomer' in col1\
        or 'astronomy' in col2:
        output = 'astronomy'
    elif 'physicist' in col1\
        or 'physics' in col2:
        output = 'physics'
    else:
        output = 'other'
    return output

# %%
df_p['code_discipline'] = df_p.apply(lambda x: code_discipline(x.occupations, x.fields), axis=1)
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                      countries           continents  \
# 0    male          Ukraine, Soviet Union         Europe, Asia
# 1  female           United States, India  North America, Asia
# 2    male                 United Kingdom               Europe
# 3    male  United States, Israel, Canada  North America, Asia
# 4    male                 Czechoslovakia               Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             academic, physicist
# 4  physicist, chemist, pharmacist
#
#                                            fields      contCode     per_25  \
# 0                                                       Eurasia  1926-1950
# 1                                                  NorthAmerica  1951-1975
# 2                                                        Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity  NorthAmerica  1901-1925
# 4                                                        Europe  1926-1950
#
#             genre_cont code_discipline
# 0         Eurasia_male         physics
# 1  NorthAmerica_female         physics
# 2          Europe_male         physics
# 3    NorthAmerica_male         physics
# 4          Europe_male         physics

# %%
df_p.groupby('code_discipline').size()
# Out:
# code_discipline
# astronomy     5811
# physics      17873
# dtype: int64

# %%
### Tableau de contingence
X = "contCode"
Y = "code_discipline"  # "0"

dddc = df_p[df_p.gender.isin(['female', 'male'])][[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
dddc
# Out:
# contCode         Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  \
# code_discipline
# astronomy            45   481      323    3343          1383      105
# physics             105  1571     1798   10967          2964      195
# Total               150  2052     2121   14310          4347      300
#
# contCode         SouthAmerica  Total
# code_discipline
# astronomy                 121   5801
# physics                   268  17868
# Total                     389  23669

# %%
### Profils des lignes
# axis=0 pour les colonnes

dddc_pl = dddc.apply(lambda x: (x/sum(x)*100*2).round(1), axis=1) 
dddc_pl
# Out:
# contCode         Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  \
# code_discipline
# astronomy           0.8   8.3      5.6    57.6          23.8      1.8
# physics             0.6   8.8     10.1    61.4          16.6      1.1
# Total               0.6   8.7      9.0    60.5          18.4      1.3
#
# contCode         SouthAmerica  Total
# code_discipline
# astronomy                 2.1  100.0
# physics                   1.5  100.0
# Total                     1.6  100.0

# %%
### Adapter à l'ordre des colonnes
col_palette_2 = [
    "#A3C1DA",  # Light Blue : Africa
    "#F4A261",  # Light Coral : Asia
    "#E3D4AD",  # Desert Sand : Eurasia
    "#DCDCDC",  # Gainsboro : Europe
    "#cd5c5c",  # Indian Red : NorthAmerica
    "#B2E0B2",  # Light Green : Oceania
    "#F6E58D",  # Light Yellow : SouthAmerica
    
]

# %%
### https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/

ax = dddc_pl.iloc[:, :-1].sort_index(ascending=False).plot(kind="barh",
                    stacked=True, figsize=(20,4), title='Proportion des disciplines par époque',
                    color=col_palette_2
                    )

### https://stackoverflow.com/questions/25447700/annotate-bars-with-values-on-pandas-bar-plots

for p in ax.patches:
    b = p.get_bbox()
    y_value=b.y1-b.y0
    ax.annotate(format(p.get_width(), '.1f'), 
                   (p.get_x() + p.get_width()/2, p.get_y() + p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   # style = 'italic',
                   weight='bold',
                   color = 'white',
                   xytext = (0, -12), 
                   textcoords = 'offset points')

ax.legend(bbox_to_anchor=(0.9, 1))

plt.show()

# %%
### Production du tableau à analyser
## Noter que pour que l'analyse soit significative en 
# termes de Chi-2 il faudrait partir de la ligne quatre
# Aussi, la dernière ligne est probablement incomplète
# en termes de génération
D = dddc.iloc[:-1,:-1].copy(deep=True)
D
# Out:
# contCode         Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  \
# code_discipline
# astronomy            45   481      323    3343          1383      105
# physics             105  1571     1798   10967          2964      195
#
# contCode         SouthAmerica
# code_discipline
# astronomy                 121
# physics                   268

# %%
## Appliquer la fonction
bivariee_stats(D)
# Out:
# Chi2 : 265.03 , dof : 6
# p-value : 2.5047376949356848e-54
# phi2 = inertie (variance totale) : 0.01174273585793133
# Cramer:  0.10581822458547405

# %% [markdown]
# ## Discipline et continent par époque

# %%
df_p.head(2)
# Out:
#                                   personUri personLabel  birthYear  gender  \
# 0  http://www.wikidata.org/entity/Q97193482   Q97193482       1941    male
# 1   http://www.wikidata.org/entity/Q4511380  Anita Goel       1973  female
#
#                countries           continents              occupations fields  \
# 0  Ukraine, Soviet Union         Europe, Asia                physicist
# 1   United States, India  North America, Asia  physicist, biophysicist
#
#        contCode     per_25           genre_cont code_discipline
# 0       Eurasia  1926-1950         Eurasia_male         physics
# 1  NorthAmerica  1951-1975  NorthAmerica_female         physics

# %%
df_p['disc_cont'] = df_p.apply(lambda x: x.contCode + '_' + x.code_discipline, axis=1)
df_p.head(2)
# Out:
#                                   personUri personLabel  birthYear  gender  \
# 0  http://www.wikidata.org/entity/Q97193482   Q97193482       1941    male
# 1   http://www.wikidata.org/entity/Q4511380  Anita Goel       1973  female
#
#                countries           continents              occupations fields  \
# 0  Ukraine, Soviet Union         Europe, Asia                physicist
# 1   United States, India  North America, Asia  physicist, biophysicist
#
#        contCode     per_25           genre_cont code_discipline  \
# 0       Eurasia  1926-1950         Eurasia_male         physics
# 1  NorthAmerica  1951-1975  NorthAmerica_female         physics
#
#               disc_cont
# 0       Eurasia_physics
# 1  NorthAmerica_physics

# %%
### Tableau de contingence
X = "disc_cont"
Y = "per_25"  # "0"

dddcp = df_p[df_p.gender.isin(['female', 'male'])][[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
dddcp
# Out:
# disc_cont  Africa_astronomy  Africa_physics  Asia_astronomy  Asia_physics  \
# per_25
# 1751-1775                 0               0               8             0
# 1776-1800                 1               0               3             0
# 1801-1825                 2               0               6             1
# 1826-1850                 2               0               4             2
# 1851-1875                 4               1               9            15
# 1876-1900                 4               3              24            59
# 1901-1925                 7              12              60           305
# 1926-1950                10              30             183           701
# 1951-1975                10              36             143           422
# 1976-2000                 5              23              41            66
# Total                    45             105             481          1571
#
# disc_cont  Eurasia_astronomy  Eurasia_physics  Europe_astronomy  \
# per_25
# 1751-1775                  3                7               124
# 1776-1800                 13                5               143
# 1801-1825                 17               11               193
# 1826-1850                 26               37               262
# 1851-1875                 36               69               357
# 1876-1900                 40               95               361
# 1901-1925                 76              422               443
# 1926-1950                 92              908               647
# 1951-1975                 18              235               619
# 1976-2000                  2                9               194
# Total                    323             1798              3343
#
# disc_cont  Europe_physics  NorthAmerica_astronomy  NorthAmerica_physics  \
# per_25
# 1751-1775             105                       2                     2
# 1776-1800             143                      10                     7
# 1801-1825             252                      33                    14
# 1826-1850             368                      69                    28
# 1851-1875             583                     109                    92
# 1876-1900             974                     113                   216
# 1901-1925            1717                     197                   844
# 1926-1950            3700                     414                  1192
# 1951-1975            2488                     351                   463
# 1976-2000             637                      85                   106
# Total               10967                    1383                  2964
#
# disc_cont  Oceania_astronomy  Oceania_physics  SouthAmerica_astronomy  \
# per_25
# 1751-1775                  0                0                       1
# 1776-1800                  2                0                       0
# 1801-1825                  2                0                       3
# 1826-1850                  8                0                       3
# 1851-1875                 16                9                       5
# 1876-1900                  6               11                       7
# 1901-1925                 21               51                      20
# 1926-1950                 20               85                      28
# 1951-1975                 22               36                      32
# 1976-2000                  8                3                      22
# Total                    105              195                     121
#
# disc_cont  SouthAmerica_physics  Total
# per_25
# 1751-1775                     0    252
# 1776-1800                     1    328
# 1801-1825                     0    534
# 1826-1850                     2    811
# 1851-1875                     7   1312
# 1876-1900                     5   1918
# 1901-1925                    39   4214
# 1926-1950                   120   8130
# 1951-1975                    79   4954
# 1976-2000                    15   1216
# Total                       268  23669

# %%
### Limiter à la période significative, 20 siècle
D = dddcp.iloc[5:-1,:-1].copy(deep=True)
D
# Out:
# disc_cont  Africa_astronomy  Africa_physics  Asia_astronomy  Asia_physics  \
# per_25
# 1876-1900                 4               3              24            59
# 1901-1925                 7              12              60           305
# 1926-1950                10              30             183           701
# 1951-1975                10              36             143           422
# 1976-2000                 5              23              41            66
#
# disc_cont  Eurasia_astronomy  Eurasia_physics  Europe_astronomy  \
# per_25
# 1876-1900                 40               95               361
# 1901-1925                 76              422               443
# 1926-1950                 92              908               647
# 1951-1975                 18              235               619
# 1976-2000                  2                9               194
#
# disc_cont  Europe_physics  NorthAmerica_astronomy  NorthAmerica_physics  \
# per_25
# 1876-1900             974                     113                   216
# 1901-1925            1717                     197                   844
# 1926-1950            3700                     414                  1192
# 1951-1975            2488                     351                   463
# 1976-2000             637                      85                   106
#
# disc_cont  Oceania_astronomy  Oceania_physics  SouthAmerica_astronomy  \
# per_25
# 1876-1900                  6               11                       7
# 1901-1925                 21               51                      20
# 1926-1950                 20               85                      28
# 1951-1975                 22               36                      32
# 1976-2000                  8                3                      22
#
# disc_cont  SouthAmerica_physics
# per_25
# 1876-1900                     5
# 1901-1925                    39
# 1926-1950                   120
# 1951-1975                    79
# 1976-2000                    15

# %%
## Appliquer la fonction
bivariee_stats(D)
# Out:
# Chi2 : 1165.14 , dof : 52
# p-value : 9.00803826971962e-210
# phi2 = inertie (variance totale) : 0.05162350145451799
# Cramer:  0.11939993020051194
